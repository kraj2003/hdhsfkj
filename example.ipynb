# %%
import pandas as pd
df =pd.read_csv('./data/final_dataset_3.csv')
df1=pd.read_csv('./data/merged_data.csv')

# %%
df.head()
# Out:
#          date      time method     url                              site  \
# 0  2025-09-23  05:30:22    GET       /         digiekycpreprod.rathi.com
# 1  2025-09-23  05:30:22    GET  /login  digiekyc1.anandrathigiftcity.com
# 2  2025-09-23  05:30:24    GET       /                digiekyc.rathi.com
# 3  2025-09-23  05:32:30    GET  /login  digiekyc1.anandrathigiftcity.com
# 4  2025-09-23  05:33:22    GET  /login  digiekyc1.anandrathigiftcity.com
#
#         client_ip  status_code  response_time            timestamp  hour  \
# 0  192.168.10.127          200              1  2025-09-23 05:30:22     5
# 1  172.16.120.124          200             13  2025-09-23 05:30:22     5
# 2   192.168.13.10          200              1  2025-09-23 05:30:24     5
# 3  172.16.120.124          200           7825  2025-09-23 05:32:30     5
# 4  172.16.120.124          200             20  2025-09-23 05:33:22     5
#
#    day_of_week  request_path_depth endpoint_base service  is_error  \
# 0            1                   1           NaN     api         0
# 1            1                   1         login     api         0
# 2            1                   1           NaN     api         0
# 3            1                   1         login     api         0
# 4            1                   1         login     api         0
#
#    is_success  is_peak_hour   CPU   RAM time_only
# 0           1             0   4.8  33.8  05:30:22
# 1           1             0   4.8  33.8  05:30:22
# 2           1             0   4.8  33.8  05:30:24
# 3           1             0   NaN   NaN  05:32:30
# 4           1             0  14.9  17.4  05:33:22

# %%
df1.tail()
# Out:
#             date      time   method  \
# 1765  2025-09-15  10:02:01     POST
# 1766  2025-09-15  10:02:29      GET
# 1767  2025-09-15  10:02:47  OPTIONS
# 1768  2025-09-15  10:03:10     POST
# 1769  2025-09-15  10:03:29      GET
#
#                                              url  \
# 1765  /api/PdfGenerator/PMSEsignProcessStatusAPI
# 1766                                      /login
# 1767                     /api/Bank/penneydropapi
# 1768                     /api/Bank/penneydropapi
# 1769                                      /login
#
#                                   site       client_ip  status_code  \
# 1765                digiekyc.rathi.com   192.168.10.88          502
# 1766  digiekyc1.anandrathigiftcity.com  172.16.120.124          200
# 1767                digiekyc.rathi.com    172.16.38.28          204
# 1768                digiekyc.rathi.com    172.16.38.28          200
# 1769  digiekyc1.anandrathigiftcity.com  172.16.120.124          200
#
#       response_time            timestamp  hour  day_of_week  \
# 1765         120355  2025-09-15 10:02:01    10            0
# 1766             14  2025-09-15 10:02:29    10            0
# 1767             34  2025-09-15 10:02:47    10            0
# 1768          22944  2025-09-15 10:03:10    10            0
# 1769             13  2025-09-15 10:03:29    10            0
#
#       request_path_depth             endpoint_base service  is_error  \
# 1765                   3  PMSEsignProcessStatusAPI     api         1
# 1766                   1                     login     api         0
# 1767                   3             penneydropapi     api         0
# 1768                   3             penneydropapi     api         0
# 1769                   1                     login     api         0
#
#       is_success  is_peak_hour  CPU  RAM time_only
# 1765           0             1  NaN  NaN  10:02:01
# 1766           1             1  NaN  NaN  10:02:29
# 1767           1             1  NaN  NaN  10:02:47
# 1768           1             1  NaN  NaN  10:03:10
# 1769           1             1  NaN  NaN  10:03:29

# %%
print("shape df",df.shape)
print("shape df1",df1.shape)
# Out:
# shape df (5227, 20)
# shape df1 (1770, 20)

# %%
df1.isnull().sum()
# Out:
# date                     0
# time                     0
# method                   0
# url                      0
# site                     0
# client_ip                0
# status_code              0
# response_time            0
# timestamp                0
# hour                     0
# day_of_week              0
# request_path_depth       0
# endpoint_base          381
# service                  0
# is_error                 0
# is_success               0
# is_peak_hour             0
# CPU                   1770
# RAM                   1770
# time_only                0
# dtype: int64

# %%
df.isna().sum()
# Out:
# date                    0
# time                    0
# method                  0
# url                     0
# site                    0
# client_ip               0
# status_code             0
# response_time           0
# timestamp               0
# hour                    0
# day_of_week             0
# request_path_depth      0
# endpoint_base         510
# service                 0
# is_error                0
# is_success              0
# is_peak_hour            0
# CPU                   479
# RAM                   479
# time_only               0
# dtype: int64

# %%
# IIS DataFrame
nan_rows_iis = df[df['CPU'].isna()]
print("NaN rows in IIS:")
nan_rows_iis.head()
# Out:
# NaN rows in IIS:
#            date      time method     url                              site  \
# 3    2025-09-23  05:32:30    GET  /login  digiekyc1.anandrathigiftcity.com
# 155  2025-09-23  06:54:23    GET  /login  digiekyc1.anandrathigiftcity.com
# 174  2025-09-23  07:06:23    GET  /login  digiekyc1.anandrathigiftcity.com
# 189  2025-09-23  07:12:23    GET  /login  digiekyc1.anandrathigiftcity.com
# 199  2025-09-23  07:18:23    GET  /login  digiekyc1.anandrathigiftcity.com
#
#           client_ip  status_code  response_time            timestamp  hour  \
# 3    172.16.120.124          200           7825  2025-09-23 05:32:30     5
# 155  172.16.120.124          200             13  2025-09-23 06:54:23     6
# 174  172.16.120.124          200             13  2025-09-23 07:06:23     7
# 189  172.16.120.124          200             14  2025-09-23 07:12:23     7
# 199  172.16.120.124          200             14  2025-09-23 07:18:23     7
#
#      day_of_week  request_path_depth endpoint_base service  is_error  \
# 3              1                   1         login     api         0
# 155            1                   1         login     api         0
# 174            1                   1         login     api         0
# 189            1                   1         login     api         0
# 199            1                   1         login     api         0
#
#      is_success  is_peak_hour  CPU  RAM time_only
# 3             1             0  NaN  NaN  05:32:30
# 155           1             0  NaN  NaN  06:54:23
# 174           1             0  NaN  NaN  07:06:23
# 189           1             0  NaN  NaN  07:12:23
# 199           1             0  NaN  NaN  07:18:23

# %%
print(df[df['timestamp'].isna()])
# Out:
# Empty DataFrame
# Columns: [date, time, method, url, site, client_ip, status_code, response_time, timestamp, hour, day_of_week, request_path_depth, endpoint_base, service, is_error, is_success, is_peak_hour, CPU, RAM, time_only]
# Index: []

# %%
df['Delay_Detected'] = (df['response_time'] > 2000).astype(int)
df['timestamp'] = pd.to_datetime(df['timestamp'])

print(f"Original data shape: {df.shape}")
print(f"Delay instances: {df['Delay_Detected'].sum()}/{len(df)} ({df['Delay_Detected'].mean()*100:.1f}%)")

# Resample to fixed intervals with proper aggregation
df_5min = (
    df.set_index('timestamp')
    .resample("5T")
    .agg({
        'Delay_Detected': 'max',  # Changed from 'sum' to 'max' - any delay in window = 1
        'response_time': 'mean',
        'CPU': 'mean',
        'RAM': 'mean', 
        # 'status_code': 'mean',
        'is_error': 'max'  # Changed from 'sum' to 'max'
    })
)

print(f"After resampling: {df_5min.shape}")
# Out:
# Original data shape: (7388, 21)
# Delay instances: 683/7388 (9.2%)
# After resampling: (366, 5)
# C:\Users\jdhintern\AppData\Local\Temp\ipykernel_30268\539454820.py:10: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   .resample("5T")

# %%
print(f"Delay instances: {df_5min['Delay_Detected'].sum()}/{len(df_5min)} ({df_5min['Delay_Detected'].mean()*100:.1f}%)")
# Out:
# Delay instances: 185.0/366 (61.7%)

# %%
df_5min.isnull().sum()
# Out:
# Delay_Detected    66
# response_time     66
# CPU               66
# RAM               66
# is_error          66
# dtype: int64

# %%
# PROPER NaN handling - use modern pandas methods
# Forward fill for system metrics (they change slowly)
df_5min['RAM'] = df_5min['RAM'].ffill().fillna(df_5min['RAM'].median())
# df_5min['CPU'] = df_5min['CPU'].ffill().fillna(df_5min['CPU'].median())

# # For response time, use forward fill then median
# df_5min['response_time'] = df_5min['response_time'].ffill().fillna(df_5min['response_time'].median())

df_5min["CPU"]=df_5min['CPU'].fillna(0)
df_5min["response_time"]=df_5min['response_time'].fillna(0)

# For categorical variables, use mode or 0
# df_5min['status_code'] = df_5min['status_code'].ffill().fillna(200)
df_5min['is_error'] = df_5min['is_error'].fillna(0)
df_5min['Delay_Detected'] = df_5min['Delay_Detected'].fillna(0)

# Create time-based features
df_5min['hour'] = df_5min.index.hour
df_5min['day_of_week'] = df_5min.index.dayofweek
df_5min['is_weekend'] = df_5min['day_of_week'].isin([5, 6]).astype(int)
# df_5min['is_peak_hour'] = df_5min['hour'].isin([9, 10, 11, 14, 15, 16]).astype(int)

# Define peak hours (example: 9 AM - 6 PM)
df_5min["is_peak_hour"] = df_5min["hour"].apply(lambda h: 1 if 9 <= h < 18 else 0)


# Rolling statistics for system health
df_5min['cpu_rolling_mean'] = df_5min['CPU'].rolling(window=6, min_periods=1).mean()
df_5min['cpu_rolling_std'] = df_5min['CPU'].rolling(window=6, min_periods=1).std()
df_5min['ram_rolling_mean'] = df_5min['RAM'].rolling(window=6, min_periods=1).mean()
df_5min['response_rolling_mean'] = df_5min['response_time'].rolling(window=6, min_periods=1).mean()

# System health indicators
df_5min['high_cpu'] = (df_5min['CPU'] > df_5min['CPU'].quantile(0.8)).astype(int)
df_5min['high_ram'] = (df_5min['RAM'] > df_5min['RAM'].quantile(0.8)).astype(int)
# df_5min['high_error_period'] = (df_5min['is_error'] > 0).astype(int)

# Create proper target - predict delays 2 periods ahead WITHOUT using current delay
# This removes data leakage completely
df_5min['future_delay'] = df_5min['Delay_Detected'].shift(-1)
df_5min['target'] = df_5min['future_delay'].fillna(0).astype(int)

# Drop rows with NaN in lag features (first few rows)
# df_5min = df_5min.dropna()

print(f"After feature engineering: {df_5min.shape}")
print(f"Target distribution: {df_5min['target'].value_counts().to_dict()}")
print(f"Target balance: {df_5min['target'].mean()*100:.1f}% positive class")
print(f"NaN values remaining: {df_5min.isnull().sum().sum()}")

print("Preprocessing complete.")
df_train = df_5min.iloc[:-5]
df_test = df_5min.tail(5)
print("train data ",df_train.tail(5))
print("test_data",df_test.head())
# Out:
# After feature engineering: (366, 17)
# Target distribution: {1: 184, 0: 182}
# Target balance: 50.3% positive class
# NaN values remaining: 2
# Preprocessing complete.
# train data                       Delay_Detected  response_time        CPU        RAM  \
# timestamp
# 2025-09-24 11:10:00             1.0     126.475610  25.095312  38.234375
# 2025-09-24 11:15:00             1.0    6923.050000  20.936842  36.615789
# 2025-09-24 11:20:00             1.0     787.839024  26.456373  37.265686
# 2025-09-24 11:25:00             1.0     658.562500  20.090323  35.958065
# 2025-09-24 11:30:00             1.0    3386.133333  21.982927  36.356098
#
#                      is_error  hour  day_of_week  is_weekend  is_peak_hour  \
# timestamp
# 2025-09-23 08:20:00             0.0      10.857143  21.900000  34.971429
# 2025-09-23 08:25:00             0.0       9.875000  15.000000  33.925000
# 2025-09-23 08:30:00             1.0    9004.391304  15.344444  33.994444
# 2025-09-23 08:35:00             0.0      10.714286   8.400000  33.666667
# 2025-09-23 08:40:00             1.0    2002.000000  22.637500  35.100000
# 2025-09-23 08:45:00             1.0    1031.333333  19.062500  34.637500
#
#                      is_error  hour  day_of_week  is_weekend  is_peak_hour  \
# timestamp
# 2025-09-23 08:00:00       1.0     8            1           0             0
# 2025-09-23 08:05:00       0.0     8            1           0             0
# 2025-09-23 08:10:00       0.0     8            1           0             0
# 2025-09-23 08:15:00       0.0     8            1           0             0
# 2025-09-23 08:20:00       0.0     8            1           0             0
# 2025-09-23 08:25:00       0.0     8            1           0             0
# 2025-09-23 08:30:00       1.0     8            1           0             0
# 2025-09-23 08:35:00       0.0     8            1           0             0
# 2025-09-23 08:40:00       0.0     8            1           0             0
# 2025-09-23 08:45:00       0.0     8            1           0             0
#
#                      cpu_rolling_mean  cpu_rolling_std  ram_rolling_mean  \
# timestamp
# 2025-09-23 08:00:00         20.084224         3.104115         34.353335
# 2025-09-23 08:05:00         19.738986         2.536034         34.391430
# 2025-09-23 08:10:00         19.113590         2.904559         34.556906
# 2025-09-23 08:15:00         20.302710         2.324381         34.614082
# 2025-09-23 08:20:00         20.581281         2.412217         34.616463
# 2025-09-23 08:25:00         19.809853         3.339652         34.527773
# 2025-09-23 08:30:00         18.902348         3.736448         34.465443
# 2025-09-23 08:35:00         16.511872         5.119937         34.247983
# 2025-09-23 08:40:00         17.582407         5.685547         34.390840
# 2025-09-23 08:45:00         17.057407         5.305213         34.382507
#
#                      response_rolling_mean  high_cpu  high_ram  future_delay  \
# timestamp
# 2025-09-23 08:00:00            1238.085660         0         0           0.0
# 2025-09-23 08:05:00            1238.204707         0         0           0.0
# 2025-09-23 08:10:00            1238.204707         0         0           0.0
# 2025-09-23 08:15:00             711.415818         0         0           0.0
# 2025-09-23 08:20:00             711.439628         0         0           0.0
# 2025-09-23 08:25:00             711.299747         0         0           1.0
# 2025-09-23 08:30:00            1508.652321         0         0           0.0
# 2025-09-23 08:35:00            1508.652321         0         0           1.0
# 2025-09-23 08:40:00            1840.628511         0         0           1.0
# 2025-09-23 08:45:00            2011.528511         0         0           1.0
#
#                      target
# timestamp
# 2025-09-23 08:00:00       0
# 2025-09-23 08:05:00       0
# 2025-09-23 08:10:00       0
# 2025-09-23 08:15:00       0
# 2025-09-23 08:20:00       0
# 2025-09-23 08:25:00       1
# 2025-09-23 08:30:00       0
# 2025-09-23 08:35:00       1
# 2025-09-23 08:40:00       1
# 2025-09-23 08:45:00       1

# %%
print(f"Delay instances: {df_5min['Delay_Detected'].sum()}/{len(df_5min)} ({df_5min['Delay_Detected'].mean()*100:.1f}%)")
# Out:
# Delay instances: 185.0/366 (50.5%)

# %%
df_train.isnull().sum()
# Out:
# Delay_Detected           0
# response_time            0
# CPU                      0
# RAM                      0
# is_error                 0
# hour                     0
# day_of_week              0
# is_weekend               0
# is_peak_hour             0
# cpu_rolling_mean         0
# cpu_rolling_std          1
# ram_rolling_mean         0
# response_rolling_mean    0
# high_cpu                 0
# high_ram                 0
# future_delay             0
# target                   0
# dtype: int64
